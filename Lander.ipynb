# %%
import gym
from stable_baselines3 import PPO

# Create the Lunar Lander environment with render_mode='human'
env = gym.make('LunarLander-v2', render_mode='human')

# Create the PPO agent with optimal hyperparameters
model = PPO('MlpPolicy', env, 
            learning_rate=0.0003,  # Learning rate
            gamma=0.99,            # Discount factor
            clip_range=0.2,        # Clip range
            ent_coef=0.01,         # Entropy coefficient
            vf_coef=0.5,           # Value function coefficient
            n_steps=2048,          # Number of steps per update
            batch_size=64,         # Batch size
            n_epochs=10,           # Number of epochs per update
            verbose=1)

# Train the model
model.learn(total_timesteps=100000)  # Train for 100,000 timesteps

# Save the trained model (optional)
model.save("ppo_lunar_lander_optimized")

# Evaluate the trained agent
obs, info = env.reset()  # Reset the environment
done = False
score = 0

while not done:
    env.render()  # This shows the pop-up visualization of the lunar lander
    action, _states = model.predict(obs)  # Get action from the trained model
    obs, reward, done, truncated, info = env.step(action)  # Take the action
    score += reward

print(f"Episode Score: {score}")  # Print the final score of the episode
env.close()  # Close the environment when done
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -182     |
# | time/              |          |
# |    fps             | 47       |
# |    iterations      | 1        |
# |    time_elapsed    | 43       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 2           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006535309 |
# |    clip_fraction        | 0.0116      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00432     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 521         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00629    |
# |    value_loss           | 1.17e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 101        |
# |    ep_rew_mean          | -188       |
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 3          |
# |    time_elapsed         | 131        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01005878 |
# |    clip_fraction        | 0.0545     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.0323    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 452        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00831   |
# |    value_loss           | 1.21e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | -174         |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 4            |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0066933176 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00534     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 556          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00764     |
# |    value_loss           | 1.19e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 5           |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008014925 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.00254    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 150         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 462         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 104        |
# |    ep_rew_mean          | -156       |
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 6          |
# |    time_elapsed         | 262        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00890968 |
# |    clip_fraction        | 0.0808     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | -0.00083   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 227        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0113    |
# |    value_loss           | 635        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 7            |
# |    time_elapsed         | 306          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0044669784 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.0259      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 341          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00312     |
# |    value_loss           | 671          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 109        |
# |    ep_rew_mean          | -126       |
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 8          |
# |    time_elapsed         | 350        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00859697 |
# |    clip_fraction        | 0.0472     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | -4.65e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 115        |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0053    |
# |    value_loss           | 304        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 9           |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009811155 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 3.43e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 299         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | -115         |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 10           |
# |    time_elapsed         | 437          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0121046025 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.000709    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 432          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 11          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006397073 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -1.24e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 106         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 242         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | -99.8       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 12          |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004083325 |
# |    clip_fraction        | 0.0062      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.00152     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 238         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | -97.6       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 13          |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006962616 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0791      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71          |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00524    |
# |    value_loss           | 181         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | -96.9        |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 14           |
# |    time_elapsed         | 612          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0068097087 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 142          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00731     |
# |    value_loss           | 222          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | -91.3        |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 15           |
# |    time_elapsed         | 655          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0043682344 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0127       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 138          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 162          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 196          |
# |    ep_rew_mean          | -91.1        |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 16           |
# |    time_elapsed         | 699          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0037351004 |
# |    clip_fraction        | 0.00264      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 126          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 227          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | -90.7       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 17          |
# |    time_elapsed         | 743         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003986329 |
# |    clip_fraction        | 0.00889     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.000705   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 170         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 535         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | -88.4       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 18          |
# |    time_elapsed         | 786         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008938482 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00624    |
# |    value_loss           | 237         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | -86.7       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 19          |
# |    time_elapsed         | 829         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006152803 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87          |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 140         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 243          |
# |    ep_rew_mean          | -77.5        |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 20           |
# |    time_elapsed         | 873          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0066666706 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.1         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00743     |
# |    value_loss           | 179          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 258          |
# |    ep_rew_mean          | -72.9        |
# | time/                   |              |
# |    fps                  | 46           |
# |    iterations           | 21           |
# |    time_elapsed         | 916          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0141414255 |
# |    clip_fraction        | 0.0687       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.474        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.4         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00701     |
# |    value_loss           | 148          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | -64.2       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 22          |
# |    time_elapsed         | 959         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006333429 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.8        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 185         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | -62.1       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 23          |
# |    time_elapsed         | 1003        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006881401 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.1        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 234         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 303        |
# |    ep_rew_mean          | -60.1      |
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 24         |
# |    time_elapsed         | 1046       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00339057 |
# |    clip_fraction        | 0.0114     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.535      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 48.4       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00374   |
# |    value_loss           | 119        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 315         |
# |    ep_rew_mean          | -59.7       |
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 25          |
# |    time_elapsed         | 1089        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008276591 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.5        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00774    |
# |    value_loss           | 130         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | -61.7       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 26          |
# |    time_elapsed         | 1132        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013887942 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.8        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00838    |
# |    value_loss           | 94.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 352         |
# |    ep_rew_mean          | -61.3       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 27          |
# |    time_elapsed         | 1175        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009039117 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0089     |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | -59.5       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 28          |
# |    time_elapsed         | 1218        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013019195 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 117         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 386          |
# |    ep_rew_mean          | -61.8        |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 29           |
# |    time_elapsed         | 1261         |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0073581436 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.1         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00684     |
# |    value_loss           | 77.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 404          |
# |    ep_rew_mean          | -61.7        |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 30           |
# |    time_elapsed         | 1304         |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0071012983 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.7         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00962     |
# |    value_loss           | 91.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 421         |
# |    ep_rew_mean          | -61.2       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 31          |
# |    time_elapsed         | 1348        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011147881 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 36.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 438         |
# |    ep_rew_mean          | -60         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 32          |
# |    time_elapsed         | 1391        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006795169 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.33        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00734    |
# |    value_loss           | 23.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 455        |
# |    ep_rew_mean          | -58        |
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 33         |
# |    time_elapsed         | 1434       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00605467 |
# |    clip_fraction        | 0.0488     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.951     |
# |    explained_variance   | 0.787      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.95       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00455   |
# |    value_loss           | 22.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 464          |
# |    ep_rew_mean          | -56.5        |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 34           |
# |    time_elapsed         | 1477         |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0065243756 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.76         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.91         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0058      |
# |    value_loss           | 26.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 480         |
# |    ep_rew_mean          | -57.8       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 35          |
# |    time_elapsed         | 1520        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009953506 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.2         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 19.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 494        |
# |    ep_rew_mean          | -56.3      |
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 36         |
# |    time_elapsed         | 1563       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00708115 |
# |    clip_fraction        | 0.0854     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.485      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 54.9       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00679   |
# |    value_loss           | 44.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 518        |
# |    ep_rew_mean          | -54.2      |
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 37         |
# |    time_elapsed         | 1606       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00872744 |
# |    clip_fraction        | 0.0754     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.969     |
# |    explained_variance   | 0.476      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.6       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00751   |
# |    value_loss           | 70.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 531          |
# |    ep_rew_mean          | -50          |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 38           |
# |    time_elapsed         | 1649         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0014960142 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.847       |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.04         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 45.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 546         |
# |    ep_rew_mean          | -47.1       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 39          |
# |    time_elapsed         | 1692        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008614937 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.944      |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.58        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 562         |
# |    ep_rew_mean          | -45         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 40          |
# |    time_elapsed         | 1735        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009432622 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.2         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 570         |
# |    ep_rew_mean          | -44.2       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 41          |
# |    time_elapsed         | 1778        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008370449 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.49        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 14          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 577          |
# |    ep_rew_mean          | -41.2        |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 42           |
# |    time_elapsed         | 1822         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0050203176 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.939       |
# |    explained_variance   | 0.826        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.19         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 10.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 591        |
# |    ep_rew_mean          | -37.3      |
# | time/                   |            |
# |    fps                  | 47         |
# |    iterations           | 43         |
# |    time_elapsed         | 1865       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01925185 |
# |    clip_fraction        | 0.0893     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.898     |
# |    explained_variance   | 0.51       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.9       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00869   |
# |    value_loss           | 57.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 604         |
# |    ep_rew_mean          | -33.2       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 44          |
# |    time_elapsed         | 1908        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010673348 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.93        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 10.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 624          |
# |    ep_rew_mean          | -30.5        |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 45           |
# |    time_elapsed         | 1951         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0077008083 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.877       |
# |    explained_variance   | 0.626        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.27         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 39.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 632          |
# |    ep_rew_mean          | -28.4        |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 46           |
# |    time_elapsed         | 1995         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0077492017 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.923       |
# |    explained_variance   | 0.731        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 73.6         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 35.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 644         |
# |    ep_rew_mean          | -24         |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 47          |
# |    time_elapsed         | 2038        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010506311 |
# |    clip_fraction        | 0.0766      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.891      |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00881    |
# |    value_loss           | 85.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 652          |
# |    ep_rew_mean          | -17.3        |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 48           |
# |    time_elapsed         | 2081         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0058503584 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.444        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 100          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 139          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 661          |
# |    ep_rew_mean          | -10.3        |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 49           |
# |    time_elapsed         | 2124         |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0044950647 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.883       |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 143          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 175          |
# ------------------------------------------
# Episode Score: 183.23086495563118
